# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv('c:/users/Risha/Downloads/archive/alzheimers_prediction_dataset.csv')
df
# Out:
#             Country  Age  Gender  Education Level   BMI  \
# 0             Spain   90    Male                1  33.0
# 1         Argentina   72    Male                7  29.9
# 2      South Africa   86  Female               19  22.9
# 3             China   53    Male               17  31.2
# 4            Sweden   58  Female                3  30.0
# ...             ...  ...     ...              ...   ...
# 74278        Russia   60  Female                3  22.6
# 74279            UK   58    Male               18  30.6
# 74280         Spain   57  Female               13  28.2
# 74281        Brazil   73  Female                7  29.0
# 74282        Norway   57  Female                1  31.7
#
#       Physical Activity Level Smoking Status Alcohol Consumption Diabetes  \
# 0                      Medium          Never        Occasionally       No
# 1                      Medium         Former               Never       No
# ...

# %%
#socioeconomic & social engagement 
#bar chart: Income level vs Alzheimer'


import plotly.graph_objects as go
import plotly.express as px
fig = px.bar(df, x='Income Level', y='Alzheimer’s Diagnosis', color='Income Level', title='Income Level vs Alzheimer\'s Disease')
fig.update_layout(xaxis_title='Income Level', yaxis_title='Alzheimer\'s Disease')
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
df = pd.read_csv('c:/users/Risha/Downloads/archive/alzheimers_prediction_dataset.csv')

# Group the data by 'Empoyment Status' and 'Alzheimer’s Diagnosis' and count occurrences
grouped = df.groupby(['Employment Status', 'Alzheimer’s Diagnosis']).size().reset_index(name='count')

# Create a stacked bar chart
fig = px.bar(grouped, 
             x='Employment Status', 
             y='count', 
             color='Alzheimer’s Diagnosis', 
             barmode='stack', 
             title="Stacked Bar Chart: Employment Status vs Alzheimer's Diagnosis")

# Update axis labels
fig.update_layout(xaxis_title="Employment Status", 
                  yaxis_title="Number of Individuals", 
                  legend_title="Alzheimer’s Diagnosis")

# Show the plot
fig.show()

# %%
heatmap_data = df.pivot_table(index='Social Engagement Level', 
                              columns='Alzheimer’s Diagnosis', 
                              aggfunc='size', 
                              fill_value=0)


# Create the heatmap using Plotly
fig = px.imshow(heatmap_data, 
                labels=dict(x="Alzheimer’s Diagnosis", y="Social Engagement Level", color="Count"),
                title="Heatmap of Social Engagement Level by Alzheimer’s Diagnosis",
                color_continuous_scale="Blues", template="plotly_dark")

# Show the heatmap
fig.show()

# %%
# Sample grouping
grouped = df.groupby(['Marital Status', 'Alzheimer’s Diagnosis']).size().reset_index(name='count')

# Create grouped bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=grouped, x='Marital Status', y='count', hue='Alzheimer’s Diagnosis')

plt.title("Marital Status vs. Alzheimer's Diagnosis")
plt.xlabel("Marital Status")
plt.ylabel("Number of Individuals")
plt.legend(title="Alzheimer’s Diagnosis")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Create a grouped bar chart
import plotly.express as px
fig = px.bar(grouped, 
             x='Marital Status', 
             y='count', 
             color='Alzheimer’s Diagnosis', 
             barmode='group', 
             title="Grouped Bar Chart: Marital Status vs Alzheimer's Diagnosis")

# Update axis labels
fig.update_layout(xaxis_title="Marital Status", 
                  yaxis_title="Number of Individuals", 
                  legend_title="Alzheimer’s Diagnosis")

# Show the plot
fig.show()
